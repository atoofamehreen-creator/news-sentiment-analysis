# %%
# !pip install pandas matplotlib seaborn textblob

# %%
import pandas as pd

# Sample news headlines
data = {
    "headline": [
        "Stock market hits record high",
        "Natural disaster causes heavy damage",
        "Local team wins championship",
        "Inflation rates continue to rise",
        "New tech product receives great reviews",
        "Political tension rises in parliament"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                   headline
# 0            Stock market hits record high
# 1     Natural disaster causes heavy damage
# 2             Local team wins championship
# 3         Inflation rates continue to rise
# 4  New tech product receives great reviews
# 5    Political tension rises in parliament

# %%
from textblob import TextBlob

# Function to get sentiment
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply function
df["sentiment"] = df["headline"].apply(get_sentiment)
df
# Out:
#                                   headline sentiment
# 0            Stock market hits record high  Positive
# 1     Natural disaster causes heavy damage  Negative
# 2             Local team wins championship  Positive
# 3         Inflation rates continue to rise   Neutral
# 4  New tech product receives great reviews  Positive
# 5    Political tension rises in parliament   Neutral

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x="sentiment", palette="Set2")
plt.title("News Sentiment Distribution")
plt.show()
# Out:
# /tmp/ipython-input-903918987.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="sentiment", palette="Set2")

# %%
import os

# Create datasets folder if it doesn't exist
os.makedirs("/content/drive/MyDrive/datasets", exist_ok=True)

# Also create subfolder for this project (optional)
os.makedirs("/content/drive/MyDrive/datasets/news_project", exist_ok=True)

# %%
df.to_csv("/content/drive/MyDrive/datasets/news_project/news_sentiment_results.csv", index=False)
print("Saved results to Drive!")
# Out:
# Saved results to Drive!
